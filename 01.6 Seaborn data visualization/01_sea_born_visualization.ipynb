# %% [markdown]
# # Sea born Visualization
# - sea born is the advance version of matplotlib
# - it is easy to use and more advance than matplot lib
# - it contains many free defined functionalities
# - works seamleslly with matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('../healthcare_dataset.csv')
df.head()
# Out:
#    patient_id           visit_date age_group  gender region        department  \
# 0           1  2022-01-01 00:00:00     31-45    Male   West  General Medicine
# 1           2  2022-01-01 01:00:00       60+  Female   West       Orthopedics
# 2           3  2022-01-01 02:00:00     46-60    Male  South        Pediatrics
# 3           4  2022-01-01 03:00:00     31-45  Female  North         Neurology
# 4           5  2022-01-01 04:00:00     18-30  Female  North         Neurology
#
#   treatment_type visit_type  length_of_stay_days  treatment_cost  \
# 0     Medication  Emergency                  5.8         59151.0
# 1        Surgery    Routine                  5.1         30272.0
# 2    Observation    Routine                  7.9         67498.0
# 3     Medication    Routine                  5.0         29896.0
# 4        Therapy    Routine                  0.0         36208.0
#
#    recovery_score  readmission_risk
# 0            59.0              0.12
# ...

# %% [markdown]
# ## 1: Axis level Plot

# %%
df=df.sample(500)
sns.scatterplot(data=df,x='treatment_cost',y='recovery_score',hue='visit_type') #hue means diffreent colors for each type
plt.title('Treatment Cost vs Recovery score')
plt.show()

# %% [markdown]
# ## 2: Figure level plot

# %%
sns.relplot(data=df,x='treatment_cost',y='recovery_score',hue='visit_type',col='gender') 
#col means it will draw two graphs for each gender
sns.set_theme(style='whitegrid')  #it will create rid lines in the white background
