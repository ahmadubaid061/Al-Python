# %% [markdown]
# # Distribution Plots

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv('../healthcare_dataset.csv')
df.head()
# Out:
#    patient_id           visit_date age_group  gender region        department  \
# 0           1  2022-01-01 00:00:00     31-45    Male   West  General Medicine
# 1           2  2022-01-01 01:00:00       60+  Female   West       Orthopedics
# 2           3  2022-01-01 02:00:00     46-60    Male  South        Pediatrics
# 3           4  2022-01-01 03:00:00     31-45  Female  North         Neurology
# 4           5  2022-01-01 04:00:00     18-30  Female  North         Neurology
#
#   treatment_type visit_type  length_of_stay_days  treatment_cost  \
# 0     Medication  Emergency                  5.8         59151.0
# 1        Surgery    Routine                  5.1         30272.0
# 2    Observation    Routine                  7.9         67498.0
# 3     Medication    Routine                  5.0         29896.0
# 4        Therapy    Routine                  0.0         36208.0
#
#    recovery_score  readmission_risk
# 0            59.0              0.12
# 1            97.0              0.11
# 2            60.0              0.19
# 3            51.0              0.47
# 4            60.0              0.40

# %% [markdown]
# ## Histplot
# - Treatment Cost Distribution

# %%
sns.histplot(data=df,x='treatment_cost',bins=30)
plt.title("Distribution of Treatment Cost")
plt.show()

# %% [markdown]
# #### merging two histograms
# - Routine vs Emergency visits

# %%
sns.histplot(data=df,x='readmission_risk',hue='visit_type',multiple='stack',bins=30)
plt.title("Re_admission by visit type")
plt.show()

# %% [markdown]
# ## kernal Density Plot

# %%
sns.kdeplot(data=df,x='recovery_score',hue='visit_type',fill=True)
plt.title("KDE of recovery score by visit type")
plt.show()

# %% [markdown]
# ## Empirical Commulative Density Plot

# %%
sns.set_theme(style='darkgrid') # background grid lines for better visibility
sns.ecdfplot(data=df,x='length_of_stay_days',hue='visit_type')
plt.title('ECDF of length of Stay Days')

plt.show()
